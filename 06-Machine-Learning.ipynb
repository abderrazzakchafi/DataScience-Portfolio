# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.0 MB 3.3 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.0 MB 3.0 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 3.5 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.0 MB 3.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.0 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 4.0 MB/s  0:00:02
# ...

# %%
import pandas as pd

df = pd.read_csv('cleaned_employees_data.csv')

from sklearn.model_selection import train_test_split

df.head()
# Out:
#         id     name   age       city  country department  salary  \
# 0      0.0      ali  25.0       lyon   france    finance  2200.0
# 1  unknown     sara  29.0  marseille   france         it  2000.0
# 2      2.0     omar  23.0    unknown  unknown    unknown  4000.0
# 3      3.0  mohamed  25.0      paris  unknown      sales  3500.0
# 4    490.0     sara  21.0  marseille   france         it  3500.0
#
#                  email  score
# 0              unknown   50.0
# 1       test@yahoo.com   90.0
# 2       test@yahoo.com  100.0
# 3  contact@outlook.com   40.0
# 4              unknown   50.0

# %%
df_numeric = pd.get_dummies(df, columns = ['department'], dtype=int)
df_numeric.head()
# Out:
#         id     name   age       city  country  salary                email  \
# 0      0.0      ali  25.0       lyon   france  2200.0              unknown
# 1  unknown     sara  29.0  marseille   france  2000.0       test@yahoo.com
# 2      2.0     omar  23.0    unknown  unknown  4000.0       test@yahoo.com
# 3      3.0  mohamed  25.0      paris  unknown  3500.0  contact@outlook.com
# 4    490.0     sara  21.0  marseille   france  3500.0              unknown
#
#    score  department_finance  department_hr  department_it  \
# 0   50.0                   1              0              0
# 1   90.0                   0              0              1
# 2  100.0                   0              0              0
# 3   40.0                   0              0              0
# 4   50.0                   0              0              1
#
#    department_marketing  department_sales  department_unknown
# 0                     0                 0                   0
# ...
