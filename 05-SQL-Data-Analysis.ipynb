# %%
import sqlite3
import pandas as pd

df = pd.read_csv("cleaned_employees_data.csv")
conn = sqlite3.connect("employees.db")
df.to_sql("employees", conn, if_exists="replace", index=False)

print("Database created ")
# Out:
# Database created

# %%
query ="""
SELECT *
FROM employees
WHERE department = "IT"
LIMIT 5;
"""

result = pd.read_sql_query(query, conn)

display(result)
# Out:
# Empty DataFrame
# Columns: [id, name, age, city, country, department, salary, email, score]
# Index: []
